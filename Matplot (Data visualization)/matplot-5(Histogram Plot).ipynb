# %% [markdown]
# # Histogram Plot

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
x=np.random.randint(10,60,(50))

# %%
x
# Out:
# array([12, 38, 53, 39, 21, 16, 32, 16, 36, 27, 28, 19, 48, 36, 17, 55, 24,
#        17, 38, 48, 19, 53, 37, 14, 25, 38, 11, 12, 36, 18, 35, 44, 26, 30,
#        19, 37, 31, 50, 21, 16, 17, 26, 56, 56, 41, 34, 25, 35, 43, 24])

# %%
num=[37, 14, 23, 52, 14, 39, 31, 41, 19, 31, 35, 57, 39, 46, 28, 58, 57,
       53, 18, 27, 43, 12, 28, 39, 53, 42, 25, 49, 23, 41, 27, 35, 53, 23,
       42, 33, 57, 29, 19, 48, 40, 58, 23, 35, 24, 17, 45, 30, 11, 46]



plt.xlabel("python",fontsize=13)
plt.ylabel("No.",fontsize=13)
plt.title("Histogram Plot",fontsize=13)


plt.hist(num,edgecolor='b')
# Out:
# (array([4., 4., 6., 5., 4., 7., 6., 4., 5., 5.]),
#  array([11. , 15.7, 20.4, 25.1, 29.8, 34.5, 39.2, 43.9, 48.6, 53.3, 58. ]),
#  <BarContainer object of 10 artists>)

# %%
num=[37, 14, 23, 52, 14, 39, 31, 41, 19, 31, 35, 57, 39, 46, 28, 58, 57,
       53, 18, 27, 43, 12, 28, 39, 53, 42, 25, 49, 23, 41, 27, 35, 53, 23,
       42, 33, 57, 29, 19, 48, 40, 58, 23, 35, 24, 17, 45, 30, 11, 46]

l=[10,20,30,40,50,60]


plt.xlabel("python",fontsize=13)
plt.ylabel("No.",fontsize=13)
plt.title("Histogram Plot",fontsize=13)


plt.hist(num,color='r',edgecolor='b',bins=l)
# Out:
# (array([ 8., 11., 11., 11.,  9.]),
#  array([10., 20., 30., 40., 50., 60.]),
#  <BarContainer object of 5 artists>)

# %%
num=[37, 14, 23, 52, 14, 39, 31, 41, 19, 31, 35, 57, 39, 46, 28, 58, 57,
       53, 18, 27, 43, 12, 28, 39, 53, 42, 25, 49, 23, 41, 27, 35, 53, 23,
       42, 33, 57, 29, 19, 48, 40, 58, 23, 35, 24, 17, 45, 30, 11, 46]

l=[10,20,30,40,50,60]


plt.xlabel("python ",fontsize=13)
plt.ylabel("No.",fontsize=13)
plt.title("Histogram Plot",fontsize=13)


plt.hist(num,"auto",(0,100),edgecolor='r')
# Out:
# (array([0., 2., 6., 6., 9., 7., 9., 6., 5., 0., 0., 0., 0., 0., 0.]),
#  array([  0.        ,   6.66666667,  13.33333333,  20.        ,
#          26.66666667,  33.33333333,  40.        ,  46.66666667,
#          53.33333333,  60.        ,  66.66666667,  73.33333333,
#          80.        ,  86.66666667,  93.33333333, 100.        ]),
#  <BarContainer object of 15 artists>)

# %%
num=[37, 14, 23, 52, 14, 39, 31, 41, 19, 31, 35, 57, 39, 46, 28, 58, 57,
       53, 18, 27, 43, 12, 28, 39, 53, 42, 25, 49, 23, 41, 27, 35, 53, 23,
       42, 33, 57, 29, 19, 48, 40, 58, 23, 35, 24, 17, 45, 30, 11, 46]



plt.xlabel("python",fontsize=13)
plt.ylabel("No.",fontsize=13)
plt.title("Histogram Plot",fontsize=13)


plt.hist(num,edgecolor='b',cumulative=-1)
# Out:
# (array([50., 46., 42., 36., 31., 27., 20., 14., 10.,  5.]),
#  array([11. , 15.7, 20.4, 25.1, 29.8, 34.5, 39.2, 43.9, 48.6, 53.3, 58. ]),
#  <BarContainer object of 10 artists>)

# %%
num=[37, 14, 23, 52, 14, 39, 31, 41, 19, 31, 35, 57, 39, 46, 28, 58, 57,
       53, 18, 27, 43, 12, 28, 39, 53, 42, 25, 49, 23, 41, 27, 35, 53, 23,
       42, 33, 57, 29, 19, 48, 40, 58, 23, 35, 24, 17, 45, 30, 11, 46]



plt.xlabel("python",fontsize=13)
plt.ylabel("No.",fontsize=13)
plt.title("Scatter Plot",fontsize=13)


plt.hist(num,edgecolor='b',bottom=20)
# Out:
# (array([4., 4., 6., 5., 4., 7., 6., 4., 5., 5.]),
#  array([11. , 15.7, 20.4, 25.1, 29.8, 34.5, 39.2, 43.9, 48.6, 53.3, 58. ]),
#  <BarContainer object of 10 artists>)

# %%
num=[37, 14, 23, 52, 14, 39, 31, 41, 19, 31, 35, 57, 39, 46, 28, 58, 57,
       53, 18, 27, 43, 12, 28, 39, 53, 42, 25, 49, 23, 41, 27, 35, 53, 23,
       42, 33, 57, 29, 19, 48, 40, 58, 23, 35, 24, 17, 45, 30, 11, 46]



plt.xlabel("python",fontsize=13)
plt.ylabel("No.",fontsize=13)
plt.title("Scatter Plot",fontsize=13)


plt.hist(num,edgecolor='b',align="mid",width=3.8)
# Out:
# (array([4., 4., 6., 5., 4., 7., 6., 4., 5., 5.]),
#  array([11. , 15.7, 20.4, 25.1, 29.8, 34.5, 39.2, 43.9, 48.6, 53.3, 58. ]),
#  <BarContainer object of 10 artists>)

# %%
num=[37, 14, 23, 52, 14, 39, 31, 41, 19, 31, 35, 57, 39, 46, 28, 58, 57,
       53, 18, 27, 43, 12, 28, 39, 53, 42, 25, 49, 23, 41, 27, 35, 53, 23,
       42, 33, 57, 29, 19, 48, 40, 58, 23, 35, 24, 17, 45, 30, 11, 46]



plt.xlabel("python",fontsize=13)
plt.ylabel("No.",fontsize=13)
plt.title("Scatter Plot",fontsize=13)


plt.hist(num,edgecolor='b',histtype="step")

#histtype :-step,fillstep,barstacked,bar
# Out:
# (array([4., 4., 6., 5., 4., 7., 6., 4., 5., 5.]),
#  array([11. , 15.7, 20.4, 25.1, 29.8, 34.5, 39.2, 43.9, 48.6, 53.3, 58. ]),
#  [<matplotlib.patches.Polygon at 0x160e7ad08d0>])

# %%
num=[37, 14, 23, 52, 14, 39, 31, 41, 19, 31, 35, 57, 39, 46, 28, 58, 57,
       53, 18, 27, 43, 12, 28, 39, 53, 42, 25, 49, 23, 41, 27, 35, 53, 23,
       42, 33, 57, 29, 19, 48, 40, 58, 23, 35, 24, 17, 45, 30, 11, 46]



plt.xlabel("python",fontsize=13)
plt.ylabel("No.",fontsize=13)
plt.title("Scatter Plot",fontsize=13)


plt.hist(num,edgecolor='b',align="mid",log='True',label="Python")

plt.legend()

# %%
num=[37, 14, 23, 52, 14, 39, 31, 41, 19, 31, 35, 57, 39, 46, 28, 58, 57,
       53, 18, 27, 43, 12, 28, 39, 53, 42, 25, 49, 23, 41, 27, 35, 53, 23,
       42, 33, 57, 29, 19, 48, 40, 58, 23, 35, 24, 17, 45, 30, 11, 46]



plt.xlabel("python",fontsize=13)
plt.ylabel("No.",fontsize=13)
plt.title("Scatter Plot",fontsize=13)


plt.hist(num,edgecolor='b',align="mid",label="Python")

plt.legend()
plt.axvline(45,color='r',label="line")
plt.grid()
plt.show()
