# %%
import matplotlib.pyplot as plt

x=[1,2,3,4]
y=[2,3,4,6]
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt

x=[2,3,4,5]
y=[1,2,3,4]

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt

x=[2,3,4,5]
y=[1,2,3,4]

c=['r','b','g','y']

plt.bar(x,y,color=c)
# Out:
# <BarContainer object of 4 artists>
