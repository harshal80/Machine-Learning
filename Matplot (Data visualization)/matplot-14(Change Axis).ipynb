# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[3,5,2,4,1]

plt.plot(x,y,color='r')


plt.show()

# %%
x=[1,2,3,4,5]
y=[3,5,2,4,1]

plt.plot(x,y)
plt.xticks(x,labels=["Python","Java","C++","C","SQL"])
plt.yticks(y)

plt.show()

# %%
x=[1,2,3,4,5]
y=[3,5,2,4,1]

plt.plot(x,y,color='r')
# plt.xlim(0,10)
# plt.ylim(0,10)

plt.axis([0,10,0,7])

plt.show()
