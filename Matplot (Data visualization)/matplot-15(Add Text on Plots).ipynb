# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[3,1,5,2,6]

plt.plot(x,y)

plt.xlabel("Python")
plt.ylabel("No.")
plt.title("Harshal Bhau na visualization")

plt.text(2,5,"Java",fontsize=15,style='italic',bbox={"facecolor":'lightgreen'})



plt.show()

# %%
x=[1,2,3,4,5]
y=[3,1,5,2,6]

plt.plot(x,y)

plt.xlabel("Python")
plt.ylabel("No.")
plt.title("Harshal Bhau na visualization")

plt.text(2,5,"Java",fontsize=15,style='italic',bbox={"facecolor":'lightgreen'})

plt.annotate('Python',xy=(2,1),xytext=(3,3),arrowprops=dict(facecolor="black",shrink=100))

plt.show()

# %%
x=[1,2,3,4,5]
y=[3,1,5,2,6]

plt.plot(x,y)

plt.xlabel("Python")
plt.ylabel("No.")
plt.title("Harshal Bhau na visualization")

plt.legend(["UP"],loc=2,facecolor="lightgreen",edgecolor='red',framealpha=0.5,shadow=True)

plt.show()
